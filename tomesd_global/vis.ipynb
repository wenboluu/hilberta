# %%
import torch

# %%
A = torch.load('/home/sz3684/diffusion/flux_svd_iccv/tensors/A/A_1.pt')

# %%
A.shape
# Out:
# torch.Size([1, 3072, 4096])

# %%
count = torch.sum((A >= 0.4) & (A <= 0.6))
print(count.item())
# Out:
# 407
